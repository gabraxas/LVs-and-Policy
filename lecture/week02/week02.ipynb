# %% [markdown]
# <a href="https://colab.research.google.com/github/gabraxas/LVs-and-Policy/blob/main/lecture/week02/week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # 2주차 · 액체추진제 로켓엔진 시스템과 구성요소
#
# ### *(원제: Liquid Propellant Engine System and Components)*
#
# 원 강의: 박순영(Soon-Young Park), 한국항공우주연구원(KARI) · psy@kari.re.kr
# 서울대학교 강의(2023.4.2) 원본 슬라이드 기반 — 로켓 추진의 기초 이론부터 엔진 시스템 설계, 연소기·터보펌프 구성요소, 시험·평가까지 다룸
#
# > 이 노트북은 원본 슬라이드의 텍스트·수식(OMML → LaTeX 변환)·표·그림을 슬라이드 순서 그대로, 개조식 한국어로 번역해 옮긴 것임. 수식은 스크린샷이 아니라 실제 LaTeX로 재구성해 노트북 안에서 그대로 읽고 편집 가능함

# %%
# ▶ 실행 전 준비 — 이 셀을 먼저 실행하세요 (약 10~20초 소요)
# !pip install -q ipywidgets
# !apt-get -qq install -y fonts-nanum > /dev/null 2>&1

import urllib.request
urllib.request.urlretrieve(
    "https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/_shared/course_interactive.py",
    "course_interactive.py")

from course_interactive import *
setup_korean_font()
print("준비 완료 — 아래 셀들을 순서대로 실행하며 강의를 진행하세요.")

# %% [markdown]
# `Who am I?`
#
# ## 발표자 소개
#
# - 이름 : 박순영(Soon Young Park)
# - 연락처 : psy@kari.re.kr
# - 소속 : 한국항공우주연구원(KARI)
# - 학력 :
#   - 서울대 기계항공공학부 학·석사(2003)
#   - KAIST 박사(2021)
# - 관심 분야 : 액체로켓엔진, 재사용발사체
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s002_img002.jpg)

# %% [markdown]
# ### "실용주의는 언제나 꿈꾸는 자들의 노력 위에 서 있다"
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s003_img002.png)
#
# - 베르너 폰 브라운(Wernher von Braun)
# - "실용주의는 언제나 꿈꾸는 자들의 노력 위에 서 있다"
# - 실용주의(Pragmatism)는 '사고(thinking)'의 기능을 현실의 설명·재현·반영으로 보지 않고, 예측·문제해결·행동을 위한 도구로 규정함
# 지식·언어·개념·의미 등 철학의 주요 주제 — 과학을 포함 — 는 그 자체의 유용성과 성과를 기준으로 판단됨
# 실용주의 철학은 '인간 경험 속 실제 검증'에 부쳐져야 하며, '아이디어의 구체적 적용'이 가능해야 함
# 실용주의는 관념론·실재론과 달리, 세계를 불변의 대상으로 보지 않고 "세계를 변화시키는 데 초점을 둠"

# %% [markdown]
# `Objective function and constraints`
#
# ## 강의 범위(Coverage)
#
# - 다룸 — 추진시스템에서 추력이란 무엇이며 어떻게 만들어내는가
# - 다룸 — 열역학에 기반한 화학추진시스템의 기초 이론
# - 다룸 — 액체로켓엔진의 기본 개념 및 연소실·터보펌프 등 핵심 구성요소의 설계 실무
# - 다룸 — 액체로켓엔진의 시험·평가
# - 다루지 않음 — 고체추진 로켓엔진
# - 다루지 않음 — 핵심 구성요소의 상세설계
# - 다루지 않음 — 시스템 엔지니어링
# - 다루지 않음 — 동역학(Dynamics)

# %% [markdown]
# ## PART · 1. 기본 개념과 이론(Basic Concept and Theory)
#
# > 핵심 질문 —
#
# > "액체로켓엔진(LRE)이란 무엇이며 어떻게 작동하는가?"

# %% [markdown]
# `1.1 서론(Introduction)`
#
# ## 세테리스 파리부스(Ceteris Paribus)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - Ceteris Paribus $\equiv$ "다른 모든 조건이 동일하다"는 뜻의 라틴어 표현
# - 경제학 분야에서 널리 쓰이는 가정
# - 단순화 및 모델링 도구
# - 고전과학의 기본 가정
# - = "세계는 단순하며 시간가역적인 기본 법칙에 의해 지배된다"
#
# </details>

# %% [markdown]
# ## 중력이란 참으로 매정한 존재로다
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 중력을 이겨내는 것은 얼마나 어려운가?
#   - 3,500 kg 우주선이 7,000 km 궤도에 위치한 경우
#   - 운동에너지는?
#     - ${ M }_{earth}=5.97 \times {10}^{24} k g$
#     - $G =6.67 \times {10}^{ - 11} { m }^{3}/( k g \cdot { s }^{2})$
#     - ${ F }_{centric}={ F }_{gravitation}$
#     - $\frac{\left( m { v }^{2} \right)}{ r }= G \frac{ m { M }_{earth}}{{ r }^{2}}$
#     - $\frac{1}{2} m { v }^{2}=\frac{1}{2} G \frac{ m { M }_{earth}}{ r }$
#     - $K E =6.67 \times {10}^{ - 11}\frac{2200 \times 5.97 \times {10}^{24}}{2 \times 7000000}$
#     - $=9.95 \times {10}^{10} J \approx 100 G J$
#     - 로켓의 평균 에너지 전환 시간 ~ 1,000초
#     - 로켓의 평균 출력 = 일/시간 = 100 MW
#     - cf) 원자력발전소 ~ 1,000 MW
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s008_img002.gif)
#
# - 출처 : "Oh Gravity, Thou Art a Heartless Bitch" - 셸든 쿠퍼(Sheldon Cooper), 빅뱅이론(The Big Bang Theory), 유튜브
#
# </details>

# %% [markdown]
# `1.2 로켓엔진의 기본 개념(Basic concept of rocket engine)`
#
# ## 제트추진의 정의
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 저장된 물질을 분사해 추력을 만들어내는 장치(G.P. Sutton 정의)
# - 추진제 질량만을 이용해 고속 분사류를 형성하는 제트엔진(위키피디아 정의)
#   - 운동량 보존(${ V }_{ e }$ : 완전팽창 노즐의 배기속도)
#     - $\left( M - m \right) \times \left( V - \Delta V \right)+ m \times \left( V - { V }_{ e } \right) - M \times V =0$
#     - $\left( M - \dot{ m } \Delta t \right) \times \left( V + \Delta V \right)+\dot{ m } \Delta t \times \left( V - { V }_{ e } \right) - M \times V =0$
#     - $M \frac{ \Delta V }{ \Delta t }=\dot{ m }{ V }_{ e }$
#     - $\lim { \Delta t \rightarrow 0} M \dot{ V }=\dot{ m }{ V }_{ e }$
#   - 추력 : $T =\dot{ m }{ V }_{ e }$  =  (단위시간당 분사 질량) × (유효 배기속도)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s009_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s009_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s009_img004.png)
#
# - Sutton, G.P. and Biblarz, O., 2001, Rocket propulsion elements, John Wiley & Sons, Inc.
#
# </details>

# %% [markdown]
# ## 로켓방정식(Rocket Equation)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 로켓방정식
#   - 진공 중 운동방정식
#     - $M \frac{ d V }{ d t }= T ={ V }_{ e }\dot{ m }= - { V }_{ e }\frac{ d M }{ d t }$
#   - 정리하면
#     - $d V = - { V }_{ e }\frac{ d M }{ M }= - { I }_{sp}{ g }_{0}\frac{ d M }{ M }$
#   - 적분하여 로켓방정식을 얻음
#   - $\Delta V ={ I }_{sp}{ g }_{0}\ln {\left( \frac{{ M }_{ i }}{{ M }_{ f }} \right) }$
# - 콘스탄틴 치올코프스키(Konstantin Tsiolkovsky)의 로켓 개념도와 계산
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s010_img003.jpg)
#
#   - 예) 단일단 궤도직접투입(SSTO)
#     - 저궤도(200km) 임무 가정 : $\Delta { V }_{orb}=7,500 m / s$, $\Delta { V }_{real}=9,100 m / s$
#     - RL-10C 엔진 비추력 : ${ I }_{sp}=460 sec$
#     - 로켓방정식으로 구한 질량비 : $\frac{{ M }_{ i }}{{ M }_{ f }}=\frac{{ M }_{ p }+{ M }_{ s }+{ M }_{pl}}{{ M }_{ s }+{ M }_{pl}}=7.518$
#     - 구조계수 : $\lambda =\frac{{ m }_{ s }}{{ m }_{ p }+{ m }_{ s }}$
#     - 추진제 질량분율 : $\zeta =\frac{{ m }_{ p }}{{ m }_{ i }}=\frac{{ m }_{ i } - { m }_{ f }}{{ m }_{ i }}$
#     - 전체 구조질량분율은 10% 미만이어야 함
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s011_img002.png)
#
# - LEO $\Delta V =9.1 k m , { M }_{pl}=4500 k g$
# - 출처 : 위키피디아
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s011_img005.jpg)
#
# - X-33 (출처 : 록히드마틴)
#
# | 제원 |  |
# |---|---|
# | 높이 | 20 m |
# | 질량 | 129,000 kg |
# | 단수 | 1 |
# | 발사이력 |  |
# | 상태 | 취소됨 |
# |  |  |
# | 엔진 상세 |  |
# | 엔진 형식 | XRS-2200 리니어 에어로스파이크 × 2 |
# | 최대추력 | 1,800 kN |
# | 추진제 | LOX/LH2 |
#
#   - 운동량 보존
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s012_img002.png)
#
# - 출처 : 스탠퍼드 AA284A 강의노트
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s013_img002.png)
#
# | 분사 질량의 운동량 | 기체의 질량과 속도 | 질량중심 좌표계의 전체 운동량 | 운동량 변화량 : Frame(N) – Frame(N-1) |
# |---|---|---|---|
# |  | $M ={ M }_{vehicle}+{ M }_{propellant}$ $V =0$ | $0=\left( { M }_{vehicle}+{ M }_{propellant} \right) \times 0$ |  |
# | $\Delta M { U }_{ e }$ | $M ={ M }_{vehicle}+{ M }_{propellant} - \Delta M$ $V = \Delta { V }_{1}$ | $0=\left( { M }_{vehicle}+{ M }_{propellant} - \Delta M \right) \Delta { V }_{1}+ \Delta M { U }_{ e }$ |  |
# | $\Delta M { U }_{ e }$ $\Delta M ({ U }_{ e }+ \Delta { V }_{1})$ | $M ={ M }_{vehicle}+{ M }_{propellant} - 2 \Delta M$ $V = \Delta { V }_{1}+ \Delta { V }_{2}$ | $0=\left( { M }_{vehicle}+{ M }_{propellant} - 2 \Delta M \right)\left( \Delta { V }_{1}+ \Delta { V }_{2} \right)+2 \Delta M { U }_{ e }+ \Delta M \Delta { V }_{1}$ | $0=\left( { M }_{vehicle}+{ M }_{propellant} - 2 \Delta M \right) \Delta {V}_{2}+ \Delta M { U }_{ e }$ |
# | $\Delta M { U }_{ e }$ $\Delta M ({ U }_{ e }+ \Delta { V }_{1})$ $\Delta M ({ U }_{ e }+ \Delta { V }_{1}+ \Delta { V }_{2})$ | $M ={ M }_{vehicle}+{ M }_{propellant} - 3 \Delta M$ $V = \Delta { V }_{1}+ \Delta { V }_{2}+ \Delta { V }_{3}$ | $0=\left( { M }_{vehicle}+{ M }_{propellant} - 3 \Delta M \right)\left( \Delta { V }_{1}+ \Delta { V }_{2}+ \Delta { V }_{3} \right)+3 \Delta M { U }_{ e }+2 \Delta M \Delta { V }_{1}+ \Delta M \Delta { V }_{2}$ | $0=\left( { M }_{vehicle}+{ M }_{propellant} - 3 \Delta M \right) \Delta {V}_{3}+ \Delta M { U }_{ e }$ |
#
# - $d V = - { V }_{ e }\frac{ d M }{ M }$
#
# </details>

# %% [markdown]
# ## 추력(Thrust)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 추력
#   - 운동량 방정식에 대한 레이놀즈 수송정리(Reynolds Transport Theorem)
#   - $\sum F =\frac{ d }{ d t }\int_{CV} { \rho \vec{ u } d V }+\int_{CS} { \rho \vec{ u }\left( \vec{ u } \cdot \vec{ n } \right) d A }$
#   - 정상상태(d/dt=0) :
#   - $\sum F =0=\int_{CS} { \rho \vec{ u }\left( \vec{ u } \cdot \vec{ n } \right) d A }$
# - 출처 : 스탠퍼드 AA284A 강의노트
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s014_img003.png)
#
# </details>

# %% [markdown]
# ## 유효 배기속도(Effective exhaust velocity)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 유효 배기속도
#   - 총 임펄스
#   - $I =\int_{0}^{ t } { Tdt }$
#   - 총 소모 추진제량
#   - ${ M }_{ P }=\int_{0}^{ t } {\dot{ m } d t }$
#   - $C =\frac{ d I }{ d { M }_{ p }}=\frac{ T }{\dot{ m }}={ U }_{ e }+\frac{{ A }_{ e }}{\dot{ m }}\left( { P }_{ e } - { P }_{0} \right)$
#   - $={ U }_{ e }\left( 1+\frac{{ P }_{ e }{ A }_{ e }}{{ \rho }_{ e }{ U }_{ e }^{2}{ A }_{ e }}\left( 1 - \frac{{ P }_{0}}{{ P }_{ e }} \right) \right)$
#   - $={ U }_{ e }\left( 1+\frac{1}{ \gamma { M }_{ e }^{2}}\left( 1 - \frac{{ P }_{0}}{{ P }_{ e }} \right) \right)$
# - 출처 : 스탠퍼드 AA284A 강의노트
#
# </details>

# %% [markdown]
# ## 배기속도 — 어떻게 배기속도 Ve를 최대화할 것인가
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 배기속도를 어떻게 최대화할 것인가
# - 이론적 최대 배기속도
#   - 정압(c.v) 조건에서의 열역학 제1법칙
#   - ${h}_{t2}={h}_{t1}+ q ={h}_{ e }+\frac{1}{2}{ U }_{ e }^{2}$
#   - 최대 배기속도는 무한팽창 시 얻어짐(${h}_{e}=0$)
#   - ${ U }_{ e , max } \sim \sqrt{2{h}_{t2}}=\sqrt{2{ c }_{ p }{ T }_{t2}}=\sqrt{\frac{2 \gamma }{ \gamma - 1} R { T }_{t2}}=\sqrt{\frac{2 \gamma }{ \gamma - 1}\left( \frac{{ R }_{ u }}{{ M }_{ w }} \right){ T }_{t2}}$
# - 이론적 최대 배기속도는 연소실 온도와 배기가스 분자량에 의해 결정됨
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s017_img002.png)
#
# - 등엔트로피 과정 복습
#   - 열역학 법칙 정리
#     - 열역학 제0법칙
#       - A가 C와 열평형, B도 C와 열평형이면 A와 B도 열평형 상태여야 함
#     - 열역학 제1법칙
#       - 에너지 보존
#       - 계는 내부에너지·열·일 세 종류의 에너지만을 가짐
#       - $d e = \delta q - \delta w$
#       - 단순 물질의 경우 일은 압력일(pressure work)뿐임
#       - $\delta w = Pdv$
#       - 엔탈피로 표현하면
#       - $d h= \delta q + vdP$
# - $e$ : 내부에너지
# - $h$ : 엔탈피
# - $q$ : 열전달량
# - $w$ : 일량
# - $P$ : 압력
# - $v$ : 비체적
# - 열역학 복습
#     - 열역학 제2법칙
#       - 외부 에너지원이 없다면 열은 항상 고온에서 저온으로 흐름
#       - 단일성분계에서 다음과 같이 정의되는 상태변수 '엔트로피'가 존재함
#       - $d s =\frac{ \delta q }{ T }$ 	$d S =\frac{ \delta Q }{ T }$
#       - 열역학 제2법칙
#       - $d { S }_{universe} \geq 0$
#       - $d { S }_{system}+ d { S }_{surroundings} \geq 0$
#       - 고립계의 경우
#       - $d { S }_{system} \geq 0$
#       - 엔트로피는 가능한 미시상태에 대한 '무질서도' 또는 '정보 부족'의 척도
#       - $S = k \ln {\left( { N }_{micro} \right)}$
# - $S$ : 엔트로피
# - $s$ : 비엔트로피
# - $T$ : 온도
#   - 이상기체($P v = R T$)의 가역·단열 과정($d s =0$) 가정 시:
#   - $\delta Q = d e + Pdv$
#   - $Tds = d \left( h - P v \right)+ Pdv$
#   - $Tds = d h - Pdv - vdP + Pdv$
#   - $Tds = d h - vdP$
#   - $d s =\frac{{ c }_{ p }}{ T } d T - \frac{ R }{ P } d P$
#   - $0=\frac{{ c }_{ p }}{ T } d T - \frac{ R }{ P } d P$
#   - $\int_{1}^{2} {\frac{{ c }_{ p }}{ T } d T } - \int_{1}^{2} {\frac{ R }{ P } d P }= const .$
#   - $\ln {\left( \frac{{ T }_{2}}{{ T }_{1}} \right)} - \frac{ R }{{ c }_{ p }}\ln {\left( \frac{{ P }_{2}}{{ P }_{1}} \right)}= const .$
# - 관을 통과하는 유동
#   - 기체가 관을 통과할 때 기체 분자는 관 벽에 의해 편향됨
#     - 유속이 음속보다 훨씬 느리면 밀도는 일정하게 유지되고 유속만 증가함
#     - 유속이 음속에 근접하면 압축성 효과를 고려해야 함
#     - [Ceteris Paribus] 유동이 매우 서서히 압축(단면적 감소)된 후 서서히 팽창(단면적 증가)하면, 유동 조건은 원래 상태로 되돌아옴
#     - 이러한 과정을 가역과정이라 함(열역학 제2법칙)
# - 1                                                                      2
# - ${ P }_{1}, { T }_{1},{ \rho }_{1}, { e }_{1}, {h}_{1}, { u }_{1}, { A }_{1}$
# - ${ P }_{2}, { T }_{2},{ \rho }_{2}, { e }_{2}, {h}_{2}, { u }_{2},{ A }_{2}$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s021_img005.png)
#
# - 먼저, 음속이란 무엇인가?
#   - '음속'이란 매질을 통한 작은 교란의 전파 속도임
#     - 교란은 기체 내 분자들의 무작위 운동에 의한 충돌을 통해 전파됨
#     - 작은 교란의 전파는 등엔트로피 과정임
#     - 전파 속도는 분자 충돌에 의존하므로, 음속은 기체의 상태에 따라 달라짐
#     - [Ceteris Paribus] 비열이 일정한 기체(칼로리 완전기체)라고 가정하면
#       - 질량보존과 운동량보존에서 출발하면:
#       - $\dot{ m }= \rho u A$	$- \frac{ d P }{ d x }= \rho u\frac{ d u}{ d x }$
#       - $\rho u = \rho a =\left( \rho + d \rho \right) \cdot ( a + d u )$
#       - $\rho a = \rho a + \rho d u + a d \rho + d \rho d u$
#       - $\rho d u = - a d \rho$
#       - $d P ={ a }^{2} d \rho$
#       - $a =\sqrt{\frac{ d P }{ d \rho }}$
# - $P$
# - $\rho$
#       - $d P / d \rho ={ a }^{2}$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s022_img005.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s022_img006.gif)
#
# - 출처 : Speed of Sound: Definition, Formula, Speed in Different Mediums (geeksforgeeks.org)
#   - 등엔트로피 유동 가정($d s =0$)과 이상기체($P = \rho R T $)로부터
#     - 비열비($\gamma$)의 정의로부터:
#     - $\gamma ={ c }_{ p }/{ c }_{ v }$
#     - ${ c }_{ p } - { c }_{ v }= R$
#     - $\frac{{ c }_{ p }}{ R }=\frac{ \gamma }{ \gamma - 1}$
#     - 기체의 엔트로피는:
#     - $d s ={ c }_{ p }\frac{ d T }{ T } - R \frac{ d P }{ P }$
#     - 등엔트로피 유동($d s =0$)의 경우
#     - ${ c }_{ p }\frac{ d T }{ T }= R \frac{ d P }{ P }$
#     - $\frac{{ c }_{ p }}{ R } d T =\frac{ R T }{ P } d P$
#     - $\frac{{ c }_{ p }}{ R } d T =\frac{ d P }{ \rho }$
#     - $\frac{{ c }_{ p }}{ R } d \left( \frac{ P }{ \rho } \right)=\frac{ d P }{ \rho }$
#     - $\left( \frac{{ c }_{ p }}{ R } \right) \cdot \left( \frac{ d P }{ \rho } - P \frac{ d \rho }{{ \rho }^{2}} \right)=\frac{ d P }{ \rho }$
#     - $\left( \frac{{ c }_{ p }}{ R } \right) \cdot \left( \frac{ d P }{ P } - \frac{ d \rho }{ \rho } \right)=\frac{ d P }{ P }$
#     - $\left( \frac{{ c }_{ p }}{ R } - 1 \right)\frac{ d P }{ P }=\left( \frac{{ c }_{ p }}{ R } \right)\frac{ d \rho }{ \rho }$
#     - $\left( \frac{1}{ \gamma - 1} - 1 \right)\frac{ d P }{ P }=\left( \frac{ \gamma }{ \gamma - 1} \right)\frac{ d \rho }{ \rho }$
#     - $\frac{ d P }{ P }= \gamma \frac{ d \rho }{ \rho }$
#     - $\frac{ P }{{ \rho }^{ \gamma }}= const .$
#     - 등엔트로피 유동의 압력-밀도 관계($\frac{ d P }{ P }= \gamma \frac{ d \rho }{ \rho }$)를 음속의 정의에 대입하면
#       - $\gamma P \frac{ d \rho }{ \rho }={ a }^{2} d \rho$
#       - $\frac{ \gamma P }{ \rho }={ a }^{2}$
#     - 온도가 더 직관적인 상태변수이므로 이상기체 상태방정식($P = \rho R T$)을 이용해 $\rho$를 $T$로 치환하면
#     - ${ a }^{2}= \gamma R T$
#     - $a =\sqrt{ \gamma R T }$
# - 등엔트로피 노즐 상관식
#   - 등엔트로피 관계식으로부터:
#   - 유동이 등엔트로피적으로 정체될 때의 전압력·전밀도를 상수로 규정할 수 있음:
#   - $\frac{ P }{{ \rho }^{ \gamma }}=\frac{{ P }_{ t }}{{ \rho }_{ t }^{ \gamma }}$
#   - $\frac{ P }{{ P }_{ t }}={\left( \frac{ \rho }{{ \rho }_{ t }} \right)}^{ \gamma }$
#   - 전온도 역시 다음과 같이 정의됨:
#   - $\frac{ \rho T }{{ \rho }_{ t }{ T }_{ t }}={\left( \frac{ \rho }{{ \rho }_{ t }} \right)}^{ \gamma }$
#   - $\frac{ T }{{ T }_{ t }}={\left( \frac{ \rho }{{ \rho }_{ t }} \right)}^{ \gamma - 1}$
#   - 밀도 형태로 나타내면:
#   - $\frac{ P }{{ P }_{ t }}={\left( \frac{ T }{{ T }_{ t }} \right)}^{\frac{ \gamma }{ \gamma - 1}}$
#   - 이제 마하수를 이용해 정체량-정압량 관계를 유도함
#   - 열역학 제1법칙에 내부에너지와 함께 운동에너지를 포함시켜야 함
#   - ${ e }_{2} - { e }_{1}+{ k }_{2} - { k }_{1}= q - w$
#   - 이동 기체의 비일(specific work)은 두 부분으로 나뉨. 유체를 이동시키거나 축을 돌리는 축일(${ w }_{sh}$)과, 기체 상태를 변화시키는 나머지 일로 구성됨
#   - $w ={\left( P v \right)}_{2} - {\left( P v \right)}_{1}+{ w }_{sh}$
#   - 그러면 에너지 보존식은
#   - ${ e }_{2} - { e }_{1}+{\left( P v \right)}_{2} - {\left( P v \right)}_{1}+{\left( \frac{{ u }^{2}}{2} \right)}_{2} - {\left( \frac{{ u }^{2}}{2} \right)}_{1}= q - { w }_{sh}$
#   - ${\left( e + P v \right)}_{2} - {\left( e + P v \right)}_{1}+{\left( \frac{{ u }^{2}}{2} \right)}_{2} - {\left( \frac{{ u }^{2}}{2} \right)}_{1}= q - { w }_{sh}$
#   - ${h}_{2} - {h}_{1}+{\left( \frac{{ u }^{2}}{2} \right)}_{2} - {\left( \frac{{ u }^{2}}{2} \right)}_{1}= q - { w }_{sh}$
#   - ${h}_{2}+{\left( \frac{{ u }^{2}}{2} \right)}_{2} - {h}_{1} - {\left( \frac{{ u }^{2}}{2} \right)}_{1}= q - { w }_{sh}$
#   - ${h}_{ t }=h+\frac{{ u }^{2}}{2}$로 정의하고, 노즐 유동에서는 $q$와 ${ w }_{sh}$를 무시할 수 있으므로:
#   - ${h}_{t2}={h}_{t1}$
# - $k$ : 비운동에너지, $k =\frac{1}{2}{ v }^{2}$
# - $q$ : 비열전달량
# - $w$ : 기체가 하는 비일
#   - 등엔트로피 과정에서는 전엔탈피가 보존됨
#   - ${h}_{ t }=h+\left( \frac{{ u }^{2}}{2} \right)$
#   - 이상기체의 경우 엔탈피는 온도의 함수임:
#   - ${ c }_{ p }{ T }_{ t }={ c }_{ p } T +\frac{{ M }^{2}{ a }^{2}}{2}={ c }_{ p } T +\frac{{ M }^{2} \gamma R T }{2}$
#   - $\frac{{ T }_{ t }}{ T }=1+\frac{{ M }^{2} \gamma R }{2{ c }_{ p }}$
#   - $\frac{{ T }_{ t }}{ T }=1+\frac{ \gamma - 1}{2}{ M }^{2}$
#   - $\frac{{ P }_{ t }}{ P }={\left( 1+\frac{ \gamma - 1}{2}{ M }^{2} \right)}^{\frac{ \gamma }{ \gamma - 1}}$
#   - $\frac{{ \rho }_{ t }}{ \rho }={\left( 1+\frac{ \gamma - 1}{2}{ M }^{2} \right)}^{\frac{1}{ \gamma - 1}}$
# - ${h}_{t0}$
# - ${h}_{t1}$
# - ${h}_{ t \ast }$
# - ${h}_{t2}$
# - $=$
# - $등엔트로피 노즐 = 전엔탈피 보존$
#   - 질량보존을 다시 살펴보면:
#   - $\dot{ m }= \rho u A$
#   - $= \rho AMa$
#   - $= \rho A M \sqrt{ \gamma R T }$
#   - $=\frac{ P }{ R T } A M \sqrt{ \gamma R T }$
#   - $= A \sqrt{ \gamma R } M \frac{ P }{\sqrt{ T }}$
#   - 등엔트로피 관계식 $P ={ P }_{ t }{\left( \frac{ T }{{ T }_{ t }} \right)}^{\frac{ \gamma }{ \gamma - 1}}$을 이용해 $P$를 $T$와 ${ P }_{ t }$로 치환하면;
#   - $\dot{ m }=\frac{ A { P }_{ t }}{\sqrt{{ T }_{ t }}}\sqrt{\frac{ \gamma }{ R }} M {\left( \frac{ T }{{ T }_{ t }} \right)}^{\frac{ \gamma +1}{2\left( \gamma - 1 \right)}}$
#   - $T /{ T }_{ t }$를 $M$으로 나타내면:
#   - $\dot{ m }=\frac{ A { P }_{ t }}{\sqrt{{ T }_{ t }}}\sqrt{\frac{ \gamma }{ R }} M {\left( 1+\frac{ \gamma - 1}{2}{ M }^{2} \right)}^{ - \frac{ \gamma +1}{2\left( \gamma - 1 \right)}}$
#   - $M =1$인 지점에서 잘 알려진 초크(choked) 유동 조건이 성립함:
#   - $\dot{ m }=\frac{{ A }_{ \ast }{ P }_{ t }}{\sqrt{{ T }_{ t }}}\sqrt{\frac{ \gamma }{ R }}{\left( \frac{ \gamma +1}{2} \right)}^{ - \frac{ \gamma +1}{2\left( \gamma - 1 \right)}}$
#
# </details>

# %% [markdown]
# ## 특성속도(Characteristic Velocity)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 특성속도 ${ c }^{ \ast }$
#   - 초크(choked) 유동 상관식을 다시 살펴보면:
#   - $\dot{ m }=\frac{{ A }_{ \ast }{ P }_{ t }}{\sqrt{{ T }_{ t }}}\sqrt{\frac{ \gamma }{ R }}{\left( \frac{ \gamma +1}{2} \right)}^{ - \frac{ \gamma +1}{2\left( \gamma - 1 \right)}}$	(1)
#   - 추력($F$)의 정의로부터
#   - $F =\dot{ m }{ V }_{ e }$	(2)
#   - 압력 ${ P }_{ t }$의 챔버를 가정하면, 목(throat) ${ A }_{ \ast }$에 작용하는 힘은:
#   - $F ={ P }_{ t }{ A }_{ \ast }$	(3)
#   - (2)와 (3)을 결합해 노즐 목의 특성속도($M =1$)를 구함 — 이를 특성속도(${ c }^{ \ast }$)라 부름
#   - $\dot{ m }{ V }_{ e }^{ \ast }={ P }_{ t }{ A }_{ \ast }$
#   - ${ c }^{ \ast } \equiv { V }_{ e }^{ \ast }=\frac{{ P }_{ t }{ A }_{ \ast }}{\dot{ m }}$	(4)
#   - 노즐 목의 질량유량을 대입하면
#   - ${ c }^{ \ast }=\frac{\sqrt{ \gamma }}{ \gamma \sqrt{{\left( \frac{2}{ \gamma +1} \right)}^{\frac{ \gamma +1}{ \gamma - 1}}}}\sqrt{\frac{{ R }_{ u }}{{ M }_{ w }}{ T }_{ t }}$
#   - 특성속도는 초음속 노즐 부분을 제외한, 연소와 화학에너지 수준이 추력 형성에 기여하는 정도를 나타내는 척도임
#   - c*가 클수록 유효 배기속도가 높고, 성능이 높음을 의미!
# - ${ M }_{ w }$ : 분자량
# - ${ R }_{ u }$ : 기체상수
#   - ${ c }^{ \ast }$에 유의미한 영향을 주는 인자는?
#     - $f \left( \gamma \right) \equiv \frac{\sqrt{ \gamma }}{ \gamma \sqrt{{\left( \frac{2}{ \gamma +1} \right)}^{\frac{ \gamma +1}{ \gamma - 1}}}}$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s030_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s030_img004.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s031_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s032_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s033_img003.png)
#
#   - 수소는 케로신 등 무거운 연료보다 분자량(MW)이 작아, 화학에너지(또는 열에너지)를 분자 운동에너지(압력·온도)로, 다시 추력을 만드는 배기속도로 변환하기가 더 유리함
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s034_img002.png)
#
# - 출처 : Daniele Bianchi, "Rocket Performance"
#
# </details>

# %% [markdown]
# ## 추력계수(Thrust Coefficient)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 추력계수 ${ C }_{ F }$
#   - 추력 방정식 복습:
#   - $T =\dot{ m }{ u }_{ e }+\left( { P }_{ e } - { P }_{ a } \right){ A }_{ e }$
#   - 추력계수(실제 추력 대 초크노즐 추력의 비):
#   - ${ C }_{ F } \equiv \frac{ T }{{ A }_{ \ast }{ P }_{t2}}$
#   - ${ C }_{ F }=\frac{\dot{ m }{ u }_{ e }}{{ A }_{ \ast }{ P }_{t2}}+\left( \frac{{ P }_{ e }}{{ P }_{t2}} - \frac{{ P }_{ a }}{{ P }_{t2}} \right)\frac{{ A }_{ e }}{{ A }_{ \ast }}$
#   - 등엔트로피·칼로리 완전기체 노즐 유동 가정 시 추력계수는 다음과 같이 표현됨
#   - ${ C }_{ F }={\left\{ \left( \frac{2{ \gamma }^{2}}{ \gamma - 1} \right){\left( \frac{2}{ \gamma +1} \right)}^{\frac{ \gamma +1}{ \gamma - 1}}\left[ 1 - {\left( \frac{{ P }_{ e }}{{ P }_{t2}} \right)}^{\frac{ \gamma - 1}{ \gamma }} \right] \right\}}^{1/2}+\left( \frac{{ P }_{ e }}{{ P }_{t2}} - \frac{{ P }_{ a }}{{ P }_{t2}} \right)\frac{{ A }_{ e }}{{ A }_{ t }}$
# - 노즐 내 충격파 유발 유동박리
#   - 서머필드(Summerfield) 기준:
#     - 박리 위험이 발생하는 조건
#     - $\frac{{ P }_{t2}}{{ P }_{ a }}>16$, 	${ \alpha }_{ e } \sim {15}^{ o }$
#     - 등엔트로피 유동 방정식으로 ${ P }_{ e }$를 계산함
#     - 박리 발생 가능 조건
#     - $\frac{{ P }_{ e }}{{ P }_{ a }}<{\left( \frac{{ P }_{ e }}{{ P }_{ a }} \right)}_{cr} \sim 0.40$
#     - ${ \alpha }_{ e }>{15}^{ o }$이면 ${\left( \frac{{ P }_{ e }}{{ P }_{ a }} \right)}_{cr}$는 더 낮아질 수 있음
#     - 대형 노즐의 경우 최신 데이터에 따르면
#     - $\frac{{ P }_{ e }}{{ P }_{ a }}<{\left( \frac{{ P }_{ e }}{{ P }_{ a }} \right)}_{cr} \sim 0.286$
#     - 박리 유동은 경사충격파 시작점 이후의 확산부를 무시함
#     - 이는 추력계수 저하폭을 제한함
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s036_img002.png)
#
#   - 최적 추력계수(빨강), 서머필드 기준(파랑)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s037_img002.png)
#
# </details>

# %% [markdown]
# ## 비추력(Specific Impulse)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 추력계수 ${ C }_{ F }$
#   - 사례 연구 — RD 180(Atlas V)과 F-1(Saturn V)
# - 출처 : Supersonic Aerodynamics: Designing Rocket Nozzles, 2016
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s038_img003.png)
#
#   - 사례 연구 — SSME와 Vulcain 2(Ariane 5)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s039_img003.png)
#
# </details>

# %% [markdown]
# ## 추력계수(Thrust Coefficient)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 추력계수 ${ C }_{ F }$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s040_img002.png)
#
# </details>

# %% [markdown]
# ## 비추력(Specific Impulse)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 특성속도(${ c }^{ \ast }$)와 추력계수(${ C }_{ F }$)의 정의를 결합해 추력을 표현하면
#   - ${ c }^{ \ast }=\frac{{ P }_{t2}{ A }_{ \ast }}{\dot{ m }}$,	${ C }_{ F }=\frac{ T }{{ A }_{ \ast }{ P }_{t2}}$
#   - $T ={ C }_{ F }{( P }_{t2}{ A }_{ \ast })$
#   - $T =\dot{ m }$ $\times \mathop{\overbrace{{ c }^{ \ast }}}\limits_{챔버 내 기체의 에너지} \times \mathop{\overbrace{{ C }_{ F }}}\limits_{노즐 내 유동}$
#   - 비추력 : 분사된 단위질량당 추력
#   - ${ I }_{sp} \equiv \frac{ T }{\dot{ m }{ g }_{0}}=\frac{{ c }^{ \ast }{ C }_{ F }}{{ g }_{0}}$
#   - 임펄스밀도 : 분사된 단위체적당 추력
#   - $\delta \equiv \frac{ T }{{\dot{ V }}_{ p }}=\frac{ T }{\dot{ m }{ g }_{0}}\frac{\dot{ m }{ g }_{0}}{{\dot{ V }}_{ p }}={ I }_{sp}{ \rho }_{ p }$
#   - 총 임펄스
#   - ${ I }_{tot}=\int_{0}^{{ t }_{ b }} { Tdt }=\int_{0}^{{ t }_{ b }} {\dot{ m }{ I }_{sp}{ g }_{0} d t }$
#   - 평균 추력
#   - $\overline{ T } \equiv \frac{1}{{ t }_{ b }}\int_{0}^{{ t }_{ b }} { Tdt =\frac{{ I }_{tot}}{{ t }_{ b }}}$
# - 비추력
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s042_img002.png)
#
# - 실제 성능
# - 출처 : Supersonic Aerodynamics: Designing Rocket Nozzles, 2016
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s043_img003.png)
#
# </details>

# %% [markdown]
# ## 비열비란 무엇인가?
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 비열비
#   - $\gamma$는 ${ c }^{ \ast }$와 ${ C }_{ F }$ 모두에 등장하며, 비열비의 정의는
#   - $\gamma ={ c }_{ p }/{ c }_{ v }$
#   - 왜 세상은 $\gamma$에 의해 지배되는가?
#   - 이유 1) 등엔트로피 과정·이상기체 상태방정식에서, 정보는 음속 $a =\sqrt{ \gamma R T }$을 통해 전달됨
#   - 이유 2) '온도'와 '기체의 에너지'의 정의로부터
#     - 첫 번째 질문) 물질의 온도란 무엇인가?
#     - 두 번째 질문) 내부에너지와 엔탈피란 무엇인가?
#   - [Ceteris Paribus] 이상기체를 가정
#     - 기체 분자의 부피를 무시
#     - 완전탄성충돌(운동량 보존)
#     - 분자 간 힘의 상호작용 없음
#     - 분자의 운동은 뉴턴 법칙을 따르며 무작위적·비상관적임
#   - 압력을 다음과 같은 거시적 물성으로 정의함
#     - 단위면적당 분자가 벽에 충돌하며 전달하는 운동량 변화
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s045_img002.gif)
#
#   - 한 변의 길이가 L인 정육면체 용기에 질량 m인 단원자분자 N개가 들어있다고 가정
#   - 벽에 작용하는 i번째 기체분자의 힘 = x축 운동량 변화량:
#   - $\Delta { p }_{xi}=\left( - m { v }_{xi} \right) - \left( m { v }_{xi} \right)= - 2 m { v }_{xi}$
#   - ${ F }_{xi}=\frac{\left| \Delta { p }_{xi} \right|}{ \Delta t }=\frac{2 m { v }_{xi}}{\frac{2 L }{{ v }_{ x }}}=\frac{ m { v }_{xi}^{2}}{ L }$
#   - 여기서 벽 충돌 시간간격은 $\Delta t =2 L /{ v }_{ x }$
#   - 전체 N개 기체분자가 벽에 작용하는 힘 F는:
#   - ${ F }_{ x }=\sum_{ i =1}^{ N } {{ F }_{xi}}=\sum_{ i =1}^{ N } {\frac{\left| \Delta { p }_{xi} \right|}{ \Delta t }}=\frac{ m }{ L }\sum_{ i =1}^{ N } {{ v }_{xi}^{2}}=\frac{ m }{ L } N {\left( { v }_{ x }^{2} \right)}_{avg}$
#   - 벽 하나에 작용하는 압력은:
#   - $P =\frac{{ F }_{ x }}{{ L }^{2}}=\frac{ m }{{ L }^{3}} N {\left( { v }_{ x }^{2} \right)}_{avg}=\frac{ m }{ V }\left( n { N }_{ A } \right){\left( { v }_{ x }^{2} \right)}_{avg}$
#   - $=\frac{ n }{ V } M {\left( { v }_{ x }^{2} \right)}_{avg}$
#   - $=\frac{ n M }{ V }{\left( \frac{1}{3}{ v }^{2} \right)}_{avg}$
#   - $=\frac{ n M }{3 V }({ v }_{rms}^{2})$
#   - $P V = n \left( \frac{ M { v }_{rms}^{2}}{3} \right)$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s046_img002.jpg)
#
# - ${ N }_{ A }$ : 아보가드로 수, ~6.02×10²³
#   - $P$, $T$, $V$의 이상기체 상태방정식 $P V = nRT$를 이용하면
#   - $\frac{ M { v }_{rms}^{2}}{3}= R T$
#   - ${ v }_{rms}=\sqrt{\frac{3 R T }{ M }}$
#   - 단위 이상기체 분자의 운동에너지는 병진운동 항으로 정의됨
#   - ${ K }_{avg}={\left( \frac{1}{2} m { v }^{2} \right)}_{avg}=\frac{1}{2} m {\left( { v }^{2} \right)}_{avg}=\frac{1}{2} m { v }_{rms}^{2}$
#   - 온도로 나타내면,
#   - ${ K }_{avg}=\frac{1}{2} m \left( \frac{3 R T }{ M } \right)=\frac{3}{2}\left( \frac{ m }{ M } \right) R T =\frac{3}{2}\left( \frac{1}{{ N }_{ A }} \right) R T =\frac{3}{2}\left( \frac{ R }{{ N }_{ A }} \right) T$
#   - 볼츠만 상수 ${ k }_{ B }= R /{ N }_{ A }$를 도입하면
#   - ${ K }_{avg}=\frac{3}{2}{ k }_{ B } T$
#   - 이 식은 온도 T에서 모든 기체분자가 질량에 무관하게 동일한 평균 운동에너지를 가진다는 것을 의미함
#   - 앞서 유도한 ${ v }_{ x }^{2}={ v }^{2}/3$ 과정에서, 움직일 수 있는 자유도 f마다 평균 운동에너지 ${ K }_{avg}=1/2{ k }_{ B } T$를 갖는다고 해석할 수 있음
#   - 즉 분자운동의 자유도 f를 알면, 분자의 운동에너지(=내부에너지)를 온도의 함수로 나타낼 수 있으며, 그 비례상수는 볼츠만 상수 ${ k }_{ B }$의 절반임
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s047_img002.gif)
#
# - 출처 : https://in.pinterest.com/pin/chemistry--207024914116267839/
#   - 이상기체의 내부에너지 $E$는 분자의 운동에너지 총합과 같음. $n$몰의 기체에는 $n { N }_{ A }$개의 분자가 있으므로
#   - $E = n { N }_{ A }{ K }_{avg}= n { N }_{ A }\frac{3}{2}{ k }_{ B } T = n { N }_{ A }\frac{3}{2}\frac{ R }{{ N }_{ A }} T =\frac{3}{2} nRT$
#   - 이제 ${ c }_{ v }$와 ${ c }_{ p }$의 정의를 다시 살펴보면
#   - ${ c }_{ v } \equiv \frac{1}{ n }\frac{d E }{d T }{\left. ​ \right|}_{ v }=\frac{3}{2} R$
#   - ${ c }_{ p } \equiv \frac{1}{ n }\frac{d H }{d T }{\left. ​ \right|}_{ p }=\frac{1}{ n }\frac{d\left( E+PV \right)}{dT}=\frac{1}{n}\frac{dE}{dT}+\frac{1}{n}\frac{d\left( nRT \right)}{dT}={c}_{v}+R=\frac{5}{2}R$
#   - 실제 기체의 경우 운동에너지는 자유도 $f$와 다음처럼 관계됨:
#   - ${ K }_{avg}= f \frac{1}{2}{ k }_{ B } T$
#   - 비열과 그 비는 다음과 같이 됨:
#   - ${ c }_{ v }=\frac{ f }{2} R$, 	${ c }_{ p }=\left( \frac{ f }{2}+1 \right) R$
#   - $\gamma =\frac{{ c }_{ p }}{{ c }_{ v }}=\frac{ f +2}{ f }$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s048_img002.jpg)
#
#   - 비열비가 크다는 것의 의미:
#     - 열용량 증가 — 비열비가 높을수록 정압 조건에서 정적 조건 대비 더 많은 열에너지를 흡수함. 즉 단위질량(또는 몰)당 열에너지 저장 능력이 더 큼
#     - 팽창 거동 — 비열비가 클수록 정압 가열 시 기체가 더 잘 팽창하는 경향을 보임. 정압 조건에서 온도를 올리는 데 정적 조건보다 더 많은 에너지가 필요하기 때문임
#     - 단열과정 — 단열과정에서는 비열비가 높을수록 동일한 압력 변화에 대해 온도 변화가 더 커짐. 단열과정에서 온도-압력 관계가 비열비에 좌우되기 때문임
#     - 음속 — 비열비가 클수록 일반적으로 기체 내 음속이 높아짐
#     - 열역학 사이클의 효율 — 오토(Otto) 사이클, 브레이턴(Brayton) 사이클, 랭킨(Rankine) 사이클 등에서 비열비는 효율에 영향을 미침. 특정 조건에서는 비열비가 높을수록 열효율이 높아질 수 있음
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s049_img002.png)
#
# </details>

# %% [markdown]
# `1.3 열화학과 추진제(Thermochemistry and Propellants)`
#
# ## 열화학과 추진제
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 열로켓(Thermal Rocket)
#   - 열로켓에서는 챔버 내 열 주입으로 추진제 분자가 열적으로 활성화됨
#   - 이 열에너지(분자의 무작위 운동)가 노즐에서 추력에 필요한 방향성 있는 속도로 변환됨
#   - 열원은 다양함
#     - 핵에너지 : 열핵로켓(Thermo-Nuclear Rockets)
#     - 화학결합 에너지 : 화학로켓
#     - 전기에너지 : 저항제트(Resistojet)·아크제트(Arcjet)
#     - 저장 추진제 자체의 열에너지 : 콜드가스 스러스터
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s050_img002.png)
#
# - 출처 : 스탠퍼드 AA284A 강의노트
#
# </details>

# %% [markdown]
# ## 성능 파라미터 비교
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s051_img001.png)
#
# - Sutton, G.P. and Biblarz, O., 2001, Rocket propulsion elements, John Wiley & Sons, Inc.
#
# </details>

# %% [markdown]
# ## 열화학과 추진제
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 화학결합에너지
#   - 생성물 형성 속도와 그 역반응(반응물 재생성) 속도가 정확히 같아지는 가역 화학반응
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s052_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s052_img003.jpg)
#
# - 출처 : https://uen.pressbooks.pub/introductorychemistry/chapter/bond-energy-and-enthalpy/
#   - 분자의 위치에너지는 결합 형태(이온결합/공유결합)에 좌우됨
# - 생성열 ${ \Delta }_{ f }{ H }^{0}$
#   - 1 bar·298.15K 등온 조건에서, 구성 원소로부터 화합물 1몰이 생성될 때 방출(또는 흡수)되는 에너지, 즉 엔탈피 변화량
#   - ${ \Delta }_{ f }{ H }_{CH4}^{0}= - 74.8\frac{ K J }{ mol }= - 4.67\frac{ M J }{ k g }$
#   - ${ \Delta }_{ f }{ H }_{H2}^{0}=0\frac{ K J }{ mol }$
# - 반응열 ${ \Delta }_{ r }{ H }^{0}$
#   - 표준상태(1 bar, 25°C)에서 반응물로부터 생성물이 형성될 때 방출·흡수되는 에너지
#   - ${ \Delta }_{ r }{ H }^{0}= \sum {\left[ { n }_{ j }{\left( { \Delta }_{ f }{ H }^{0} \right)}_{ j } \right]}_{products} - \sum {\left[ { n }_{ j }\left( { \Delta }_{ f }{ H }^{0} \right) j \right]}_{reactants}$
# - 연소열 ${ \Delta }_{ c }{ H }^{0}$
#   - 연료가 산소와 완전연소할 때 방출·흡수되는 에너지
#   - ${ H }_{CH4}^{ c }=50.00\frac{ M J }{ k g }$ (LHV)
#   - ${ H }_{H2}^{ c }=141.80\frac{ M J }{ k g }$ (LHV)
#   - ${ H }_{kerosene}^{ c }=43.00\frac{ M J }{ k g }$ (LHV)
# - 생성열
#   - 화학에너지(기준 에너지 상태 대비 화학결합에 저장된 에너지)
#   - 화학반응의 방출열 추정에 핵심적임
#   - 화합물의 생성열 결정 방법
#     - 열량계(bomb calorimeter) 측정(반응열로부터)
#     - 양자역학적 계산
#     - 결합에너지 기반 경험적 추정법
#   - 결합가법성(Bond additivity)
#     - 결합의 종류와 개수를 파악해 결합별 에너지를 합산
#     - 정확도 5% 수준
#   - 그룹가법성(Group additivity)
#     - 작용기의 종류와 개수를 파악해 그룹별 에너지를 합산
#     - 정확도 2% 수준
#   - 결합에너지법은 공유결합에 유효하며 고분자에도 적용 가능
#   - 복잡한 유기화합물에 대해 상당히 효과적
#   - NaCl과 같은 이온성 화합물에는 이 방법을 적용하지 말 것
#   - 큐베인(Cubane)처럼 결합각이 크게 뒤틀린 화합물에는 사용하지 말 것
#   - 비열·엔트로피 등 다른 물성 예측에도 활용 가능
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s054_img002.jpg)
#
# </details>

# %% [markdown]
# ## 열화학과 추진제
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 단열화염온도(Adiabatic flame temperature)
#   - 반응에서 나온 모든 에너지가 연소생성물 가열에만 쓰인다면 도달하는 온도가 단열화염온도임
#   - 주어진 추진제의 화학조성, 혼합비(O/F ratio), 상태량(온도·압력)으로부터 계산 가능
#   - 열역학 제1법칙으로부터
#   - ${ H }_{reactant}={ H }_{product}$
#   - $\sum_{reactant} {{ n }_{ i }{\left[ {h}_{ f }^{0}+ \Delta h \right]}_{ i }=\sum_{product} {{ n }_{ e }{\left[ {h}_{ f }^{0}+ \Delta h \right]}_{ e }}}$
#   - $\Delta { H }_{reaction}=\sum_{ products , e } {\int_{{ T }_{ref}}^{{ T }_{ad}} {{ n }_{ e }{ C }_{ p , e } d T }}$
# - 1.3 열화학과 추진제
#
# </details>

# %% [markdown]
# ## 열화학과 추진제
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 단열화염온도
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s056_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s056_img003.png)
#
# - 출처: M. Jadidi (2015)
#
# </details>

# %% [markdown]
# ## 액체연료의 열역학적 물성
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 출처 : NASA
#
# | 연료 | 화학식 | 생성열 | 임계온도 | 임계압력 | 기화열 |
# |---|---|---|---|---|---|
# |  |  | [KJ/mol] | [K] | [MN/m2] | [KJ/mol] |
# | Aerozine-50 | 50% 히드라진/50% UDMH | 51.51 | 607 | 11.935 | 33.67 |
# | 암모니아 | NH3 | -71.71 | 405.4 | 11.28 | 23.56 |
# | Diethylcyclohexane | (C2H5)2C6H10 | -726.18 | 638.6 | 2.534 | 38.79 |
# | Diethylenetriamine (DETA) | (NH2C2H4)2NH | -77.4 | 496 | 3.71 | 50.5 |
# | 비대칭디메틸히드라진 (UDMH) | (CH3)2N2H2 | 51.63 | 523 | 5.978 | 35.02 |
# | 에탄올 | C2H5OH | -277.65 | 516 | 6.378 | 38.79 |
# | 에틸렌옥사이드 | C2H4O | 25.15 | 468.9 | 7.191 | 25.48 |
# | Furfylene oxide | C5H5OOH | -276.35 | 572 | 3.5 | 53.62 |
# | 히드라진 | N2H4 | 50.42 | 653 | 14.693 | 43.43 |
# | 수소 | H2 | -9.01 | 33.21 | 1.296 | 0.915 |
# | 케로신 (RP-1) | H/C=2.0 | -26.03 | 676.5 | 2.172 | 49.79 |
# | 메탄 | CH4 | -89.5 | 191 | 4.64 | 8.91 |
# | 메탄올 | CH3OH | -239.03 | 513 | 7.87 | 39.32 |
# | 모노메틸히드라진 (MMH) | CH3N2H3 | 54.84 | 585 | 8.24 | 40.38 |
# | 니트로메탄 | CH3NO2 | -139.03 | 587.9 | 6.314 | 38.28 |
# | n-프로필나이트레이트 | C3H7NO3 | -214.47 | 580 | 4.05 | 34.68 |
#
# </details>

# %% [markdown]
# ## 추진제(Propellant)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 추진제의 핵심 물성
#   - Isp 성능 : 질량 최소화
#   - 밀도 또는 임펄스밀도 : 부피 최소화
#   - 저장온도에서의 물리적 상태
#     - 기체/액체/고체
#     - 저장성 : 극저온(cryogenic) vs. 지구상온 저장가능(H2O2, N2O4)
#     - 운용온도에서의 증기압:
#       - 자체가압형(N2O)
#       - 펌프공급 시스템의 얼리지(ullage) 압력
#   - 화학반응속도론
#     - 연소안정성
#     - 효율
#     - 점화 특성 : 자발화(hypergolic) 여부
#   - 독성 : 급성·만성·발암성
#   - 안정성 : 자기분해 저항성(H2O2)
#   - 부식 특성 (질산, IRFNA 등)
#   - 비용
#   - 달·화성에서의 현지자원활용(ISRU)
# - 산화제의 물성
#   - 액체 산화제
#   - 고체 산화제
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s059_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s059_img003.png)
#
# - 출처 : KOC University, AA284, "Advanced Rocket Propulsion"
# - 연료의 물성
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s060_img003.png)
#
# - 화학추진시스템의 성능
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s061_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s062_img003.png)
#
# - 로켓추진용 케로신의 발전 과정
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s063_img002.png)
#
# </details>

# %% [markdown]
# ## LOX/케로신
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 저장성 우수(케로신), 무독성(취급 용이)
# - 저비용
# - 냉각 성능은 낮은 편(필름냉각 병행)
#   - k = 0.12 J/m-K @T=300K (물의 k=0.61)
#   - Pr = (점성확산율)/(열확산율) = Cp × μ/k ~ 30
#   - (물의 Pr = 6.9)
#     - LCH4 @ 110 K ~ 2
# - 연료과잉 예연소기(fuel-rich preburner)에는 그을음(soot) 생성으로 부적합
# - 밀도가 높아 부스터단에 적합
#
# </details>

# %% [markdown]
# ## LOX/LH2
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 극저온
# - 저밀도
# - 높은 비추력(상단에 적합)
# - 사례
#   - RL-10(미국, Centaur), RD-0128(러시아), HM7B(유럽, Ariane 계열), YF-75D(중국, CZ-5B), LE5(일본, H-II), KVD-1(인도, GSLV 3단)
# - 국내 현황
#   - 인프라 부족
#
# </details>

# %% [markdown]
# ## LOX/CH4
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 극저온
# - LH2와 케로신의 중간 밀도(싱글샤프트 터보펌프 적용 가능)
# - 냉각 성능 우수(코킹 온도가 높음)
# - 연료과잉 예연소기 적용 가능
# - 저비용(케로신 대비 1/3 수준)
# - 비추력 우수(케로신 대비 3% 높음)
# - 자원고갈 대응 및 행성탐사에 유리
#   - CO2+4H2 -> CH4+2H2O (사바티에 반응, Sabatier process)
#
# </details>

# %% [markdown]
# `1.4 엔진 동력 사이클(Power Cycle of Engine)`
#
# ## 로켓엔진 개발 현황
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# |  | 지상시험·미사일·발사체용 개발/개발중 |  |  | 실제 우주발사체에 사용 |  |  |
# |---|---|---|---|---|---|---|
# |  | 전세계 | 미국 | 러시아 | 전세계 | 미국 | 러시아 |
# | 엔진 | 1248 | 428 | 478 | 215 | 88 | 59 |
# |  |  | (34.3%) | (38.3%) |  | (40.9%) | (27.4%) |
# | 단(Stage) | 844 | 431 | 236 | 297 | 117 | 85 |
# |  |  | (51.1%) | (28.0%) |  | (39.4%) | (28.6%) |
# | 발사체 | 3109 | 1439 | 824 | 194 | 94 | 55 |
# |  |  | (46.3%) | (26.5%) |  | (48.5%) | (28.4%) |
#
# - www.astronautix.com 데이터 사용
# - 우크라이나·구소련은 러시아에 포함
#
# </details>

# %% [markdown]
# ## 가압식 엔진(Pressure-fed engines)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s068_img001.png)
#
# - 터보기계를 구동하지 않으므로 엄밀히는 사이클이 아니며, 비교 기준으로 활용됨. 가장 단순한 시스템이지만 펌프공급 시스템 대비 성능 제약이 가장 큼
#   - 신뢰성 우수
#   - 시동·정지가 견고함
#   - "즉응 추력(Thrust on demand)"
#   - 저장성 우수
#   - 스로틀링 성능 우수
#   - 성능은 수용 가능한 수준
#   - 추력과 탱크중량 간 트레이드오프
#   - 사례
#   - Aerojet AJ10-190 (STS)
#   - Aerojet AJ10-118 (Delta II)
#   - 대다수 RCS/ACS 시스템
# - 출처 : AIAA / NASA LPTC 강의노트
#
# | 상단 엔진 | 발사체 | 추력(ton) | Isp(sec) | Pcc(bar) | 연소시간(sec) | 추진제 |
# |---|---|---|---|---|---|---|
# | Aestus | Ariane 5 G, V | 3 | 324 | 11 | 1,100 | N2O4/MMH |
# | AJ10-118K | Delta II | 4.45 | 321 | 8.96 | 444 | N2O4/A-50* |
# | Kestrel | Falcon 1 | 3.4 | 317 | 9.3 | 418 | LOX/Kerosene |
# | PSLV-4 | PSLV | 0.7 | 308 | 8.4 | 425 | N2O4/MMH |
# | OME | Shuttle OMS | 2.73 | 316 | 8.62 | 1,250 | N2O4/MMH |
# | Vega-Avum | Vega(개발중) | 0.25 | 315.5 | 20.4 | 667 | N2O4/MMH |
#
# - A-50 = 히드라진 50% + UDMH 50%
#
# </details>

# %% [markdown]
# ## 터보펌프 공급식 엔진(Turbopump-fed engine)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 단일추진제 가스발생기(Monopropellant GG)
#   - 초기/원형 동력사이클
#   - 성능은 수용 가능한 수준
#   - 독립적인 단일추진제 제어로 신뢰성은 높지만, 제3추진제 탑재로 중량이 증가함
#   - 사례
#   - A-4 (V-2)
#   - A-6 (Navaho-I)
#   - A-7 (Redstone)
#   - RD-107/108 (R-7 계열)
#   - XLR99-RM-1 (X-15)
#   - AR2-3A (F-104)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s070_img002.png)
#
# - 출처 : AIAA / NASA LPTC 강의노트
# - 이원추진제, 단일 터보펌프(Bipropellant, Single TPA)
#   - 단일추진제 GG 대비 성능 향상
#   - 부트스트랩 시동
#   - 제3추진제를 없애 추중비(T/W) 개선
#   - 유사한 유체물성(밀도·점도)을 갖는 추진제 조합(LO2/RP-1)에 적합 — 공통 축 RPM 사용 가능
#   - KSLV-II 엔진(75톤급, 7톤급)
#   - F-1
#   - Atlas MA-2, -3, -5, -5A
#   - Navaho-II, -III
#   - MC-1 / Fastrac / Merlin
#   - S-3D → H-1 → RS-27
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s071_img002.png)
#
# - 이원추진제 GG, 이중 터보펌프, 직렬터빈(Series Turbines)
#   - 독립적인 추력·혼합비(MR) 제어 가능
#   - 서로 다른 펌프 회전수를 요구하는 유체물성(LO2/LH2)의 추진제 조합에 적합
#   - J-2 → J-2X
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s072_img002.png)
#
# - 이원추진제 GG, 이중 터보펌프, 병렬터빈(Parallel Turbines)
#   - 서로 다른 펌프 회전수를 요구하는 유체물성(LO2/LH2)의 추진제 조합에 적합
#   - Vulcain
#   - RS-68
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s073_img002.png)
#
# - 탭오프 사이클(Tapoff Cycle)
#   - 메인 챔버에서 뽑아낸 고온가스로 터보펌프 구동
#   - 스로틀링 성능 우수
#   - 운용 경험은 적음
#   - 단순한 구조로 잠재적 고신뢰성 확보 가능
#   - J-2S
#   - Blue Origin의 BE-3
#   - Firefly의 엔진
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s074_img002.png)
#
# - 팽창기 사이클(Expander Cycle) — 단일 터보펌프
#   - 가열 가능한 연료량에 따라 추력이 제한됨
#   - 일을 뽑아내기 위해 높은 열전달 효율 및/또는 다단터빈이 필요함
#   - 추중비(T/W)에 불리
#   - 신뢰성 높음
#   - 고장 모드가 비교적 온건함
#   - RL10 계열
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s075_img002.png)
#
# - 팽창기 사이클 — 이중 터보펌프
#   - 터빈 바이패스로 독립적 추력·혼합비(MR) 제어 가능
#   - 가열 가능한 연료량에 따라 추력이 제한됨
#   - RL60
#   - MB-xx
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s076_img002.png)
#
# - 다단연소 사이클(Staged-combustion cycle)
#   - 모든 추진제를 추력 생성에 활용
#   - 고성능(추력, Isp, T/W)
#   - 높은 Isp를 위해 고압 운용이 필요함
#   - 신뢰성은 좋으나 고압 운용조건에서 세심한 관리가 필요
#   - 고압 운용을 위해 통상 부스트펌프로 메인펌프 유입압력을 높여야 함
# - 다단연소 사이클의 변형
#   - 연료과잉형(FRSC)
#   - LO2/LH2 추진제에 주로 사용. 예) Arroway 엔진(개발 중단)
#   - 산화제과잉형(ORSC)
#   - LO2/케로신 추진제에 주로 사용
#   - NTO/UDMH도 사용
#   - 완전유량형(FFSC)
#   - LO2/LH2 추진제 기반 실험 시스템(IPD) 1건 개발됨
#   - SpaceX의 Raptor가 대표적 사례
# - 연료과잉 다단연소 사이클 — 이중 예연소기(Dual Preburners)
#   - 독립적 혼합비·추력수준 스로틀링 가능
#   - SSME
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s078_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s078_img004.png)
#
# - 부스트펌프 미적용
# - 부스트펌프 적용
# - 연료과잉 다단연소 사이클 — 단일 예연소기, 이중 터보펌프
#   - 일부 혼합비·추력수준 스로틀링 가능
#   - 이중예연소기(DPFRSC) 대비 시스템이 단순해 신뢰성이 더 높음
#   - RD-0120
#   - LE-7
#   - RS-30 ASE (DDT&E 미완료)
#   - COBRA (DDT&E 미완료)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s079_img003.png)
#
# - 산화제과잉 다단연소 사이클 — 단일 터보펌프, 부스트펌프 적용
#   - 신뢰성 우수
#   - 산화제 과잉 환경에서 발화에 강한 소재 필요
#   - 특수 코팅이 요구됨
#   - 러시아에서만 독점적으로 사용됨
#   - RD-253
#   - RD-170 계열
#   - RD-170, -171, -172
#   - RD-180
#   - RD-191
#   - RS-84 (DDT&E 미완료)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s080_img003.png)
#
# - 완전유량 다단연소 사이클(Full-Flow SC Cycle) — 이중 터보펌프, 이중 예연소기
#   - 시스템 복잡도 증가로 신뢰성 저하·비용 증가
#   - 유동 관리가 복잡해 복잡한 과도상태·메인스테이지 제어가 필요
#   - IPD (Integrated Powerhead Demonstrator)
#   - Raptor (Starship)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s081_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s082_img001.png)
#
# - 완전유량 다단연소 사이클 — Raptor
# - 출처 : https://www.reddit.com/r/spacex/comments/cxkrtb/detailed_diagram_of_the_raptor_engine_er26_gimbal/
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s083_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s083_img004.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s083_img005.jpg)
#
# - 전동펌프 엔진(Electrical pump engine)
#   - 배터리 : 리튬폴리머
#   - 개발부담 중간 수준
#   - 엔진 제어 용이
#   - 사례 : Rutherford(Electron 발사체)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s084_img002.png)
#
# - http://www.popsci.com/rocket-labs-got-3d-printed-battery-powered-rocket-engine
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s084_img004.png)
#
# - H.-D. Kwak et al. 2018
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s084_img006.png)
#
# </details>

# %% [markdown]
# ## 연소실 압력의 발전 추세
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s085_img001.png)
#
# </details>

# %% [markdown]
# ## PART · 2. 액체로켓엔진 시스템 설계 프로세스(System Design Process of LRE)
#
# > 액체로켓엔진 설계의 일반 절차

# %% [markdown]
# `2.1 시스템 설계 프로세스(System Design Process)`
#
# ## 액체로켓엔진 설계 프로세스
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - Sciorelli, F., Jones, M and Forde, S, Collaborative propulsion system analysis tool for pumpfed liquid rocket engines, AIAA 2005-444
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s087_img002.jpg)
#
# - Humble, R.W., Henry, G.N., and Larson, W.J., Space propulsion analysis and design, McGraw-Hill, Inc., 1995, p.193
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s088_img002.jpg)
#
# </details>

# %% [markdown]
# ## 시스템 분석 사례
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s089_img001.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s089_img002.png)
#
# - O'Brien, C.J. and Ewen, R.L., 1981, Advanced oxygen-hydrocarbon rocket engine study, NASA-CR-161748
# - 사이클 × 추진제 조합
# - 사이클 결정을 위한 가중치
#
# </details>

# %% [markdown]
# ## 액체로켓엔진 시스템 설계
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img001.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img004.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img005.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img006.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img007.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img008.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img009.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img010.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s090_img011.png)
#
# - 요구사항 검토
# - 기능 배분
# - 스크리닝
# - 유산기술(heritage) 활용
# - 분석
# - 시뮬레이션
# - 아키텍처 결과
#
# </details>

# %% [markdown]
# ## 액체로켓엔진 설계 프로세스
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 설계-분석 사이클(Design and Analysis Cycle)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s091_img002.png)
#
# - Cai, G., Tong, X., Zheng, Y. and Fang, J., 2005, "Generic optimization of system parameters for liquid rocket engine with gas generator cycle," AIAA 2005-3743
#
# </details>

# %% [markdown]
# ## 질량 마진 관리
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 질량 관리(Mass management)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s092_img002.jpg)
#
# </details>

# %% [markdown]
# ## 질량 마진 사례
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - [1] Cho, W.K., 2008, Literature survey of mass margin for space systems, KARI-RET-TM-2008-003, p.10
#
# | 사례 | 질량마진(%) | 비고 |
# |---|---|---|
# | MER[1] | 15/5 | PDR 시점 |
# | Mars pathfinder | 20 | 질량마진 |
# | SSME | 14 | 개발 중 질량 증가분 |
# | RLV study | 15 | 전체 서브시스템 권고 질량마진 |
# | AIAA | >15 | 그린등급 권고치 |
# | F-1 | 30 | 개발 중 질량 증가분 |
# | ATV | 10 | 비행체 질량마진 |
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s094_img001.png)
#
# </details>

# %% [markdown]
# ## PART · 3. 액체로켓엔진 구성요소 설계(Component Design of LREs)
#
# > 연소실(CC)과 터보펌프(TP)에 대한 개요

# %% [markdown]
# `3.1 연소실(Combustion Chamber)`
#
# ## 연소실 설계
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 연소실 설계 단계
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s096_img002.png)
#
# - 단위부품 설계 -> 조립체(Assy) 설계
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s097_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s097_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s098_img002.png)
#
# - AIAA, LPTC 강의노트, 2019
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s099_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s099_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s100_img002.png)
#
# </details>

# %% [markdown]
# ## 연소실/가스발생기(CC/GG) 설계
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 제작 및 시험
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s101_img002.png)
#
# </details>

# %% [markdown]
# ## 연소실 설계
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 연소실 제작 방식
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s102_img002.png)
#
# </details>

# %% [markdown]
# ## 연소불안정(Combustion instability)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 비행체·엔진 시스템 내 다양한 요인이 다양한 주파수·진폭의 압력진동을 유발할 때 발생함
# - 압력진동 주파수에 따라 세 가지로 분류됨
#   - 처깅(Chugging, 10-400 Hz) — 추진제 공급계 또는 비행체와 연소실 간 상호작용에 기인
#   - 버징(Buzzing, 400-1000 Hz) — 엔진 구조, 혼합비, 추진제 공급계 공진과의 상호작용에 기인
#   - 스크리밍(Screaming, >1000 Hz) — 연소실 내 연소 과정 및 음향공진 특성에 기인
# - 연소불안정의 모드
#   - 접선(Tangential) 모드
#   - 반경(Radial) 모드
#   - 복합(Combined) 모드
#   - 종(Longitudinal) 모드
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s103_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s103_img003.png)
#
# - 연소불안정의 위험성
#   - 열적 안정성 붕괴
#   - 경계층 손상
#   - 벽면으로의 강한 열유속 발생
#   - 파손·파괴 발생
#   - 강한 진동 수반
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s104_img002.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s104_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s105_img001.png)
#
# - 연소불안정의 원인
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s105_img003.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s105_img004.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s105_img005.jpg)
#
# - (동적 안정성 기준 : τdecay ≤ 15 ms)
# - 헤드 설계 변경에 따른 연소실 동압 비교(정적 안정성 기준 : p′rms/pc ≤ 3%)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s105_img008.png)
#
# - 75톤급 연소기 개발모델(DM)을 통한 연소안정성 설계 검증 사례
# - 새턴V 단일단 F-1 엔진의 연소불안정 사례
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s106_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s106_img003.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s106_img004.jpg)
#
# </details>

# %% [markdown]
# ## 열전달(Heat transfer)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 연소실 하중
# - 기계적 하중(압력·압력진동, 노즐 측면하중)
# - 열적 하중(탄소성 변형, 크리프, 피로)
# - 그 외(화학적, 물리적 요인 등)
# - 냉각이 "핵심(key)"
# - 재생냉각(용접튜브, 밀드채널)
# - 열차폐코팅(금속, 금속산화물)
# - 필름냉각(혼합비 편향, 필름·트랜스피레이션·삭마 냉각)
# - 복사냉각
# - 열유속 40 MW/m² 이상
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s108_img002.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s108_img003.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s108_img004.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s109_img001.png)
#
# - AIAA, LPTC 강의노트, 2019
# - 고온가스측(Hot gas side)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s110_img001.png)
#
# - 냉각재측(Cold gas side)
#
# </details>

# %% [markdown]
# `3.2 터보펌프(Turbopump)`
#
# ## 터보펌프의 동력 수준
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s111_img001.png)
#
# </details>

# %% [markdown]
# ## 속도삼각형(Velocity triangle)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s112_img001.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s113_img001.png)
#
# </details>

# %% [markdown]
# ## 펌프(Pump)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s114_img001.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s114_img002.png)
#
# </details>

# %% [markdown]
# ## 원심펌프(Centrifugal pump)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s115_img001.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s116_img001.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s117_img001.png)
#
# </details>

# %% [markdown]
# ## 터빈(Turbine)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s118_img001.png)
#
# - 충동터빈(Impulse Turbine)은 작동가스의 운동에너지만으로 터빈로터를 회전시킴
# - 반동터빈(Reaction Turbine)은 작동유체의 압력에너지와 운동에너지를 모두 이용해 터빈로터를 회전시킴
# - 충동터빈은 고낙차·저유량 응용(수력발전 등, 유체가 고압으로 공급되는 경우)에 주로 사용됨
# - 반동터빈은 저낙차·고유량 응용(수력발전 등, 유체가 저압으로 공급되는 경우)에 주로 사용됨
# - 액체로켓엔진 설계 프로세스의 핵심 결정 변수
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s119_img002.png)
#
# - R.W. Humble, G.N. Henry and W.J. Larson, Space propulsion analysis and design, p.261
#
# </details>

# %% [markdown]
# ## 터보펌프
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s120_img001.png)
#
# </details>

# %% [markdown]
# ### 출처 : www.reddit.com
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s121_img001.gif)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s121_img002.png)
#
# - 출처 : www.reddit.com
#
# </details>

# %% [markdown]
# ## 회전속도의 선정
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 인듀서(Inducer)
# - 임펠러(Impeller)
# - 캐비테이션(Cavitation) :
#   - 액체 온도가 증기압점보다 높거나, 압력이 증기압보다 낮을 때 기포가 발생함
# - 임계점(Critical point) : 유량이 일정 비율만큼 감소하는 지점
# - NPSH, 유효흡입양정(available Net Positive Suction Head) :
#   - $NPS { H }_{ a }=\frac{{ P }_{ t , i n } - { P }_{vap}}{ \rho g }$
# - NPSHr, 필요흡입양정(required Net Positive Suction Head) : 캐비테이션 발생 임계점 이상으로 요구되는 최소 입구압력
# - $\sigma$, 캐비테이션수(Cavitation number) :
#   - $\sigma =\frac{{ P }_{ t , i n } - { P }_{vap}}{0.5 \rho { U }_{ t }^{2}}$ : 입구압력과 증기압의 차이를, 인듀서 날개 앞전의 접선속도로 얻어지는 동압으로 정규화한 값
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s122_img002.png)
#
# </details>

# %% [markdown]
# ## NPSH, 유효흡입양정(Net Positive Suction Head)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 인듀서 : 터보펌프가 캐비테이션 없이 고회전 운전을 하도록 지원
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s123_img002.jpg)
#
# - Kang, 2019
# - $NPS { H }_{ r }> NPS { H }_{ a }$
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s124_img001.png)
#
# - $NPS { H }_{ a }=\frac{{ P }_{0} - \Delta P - { P }_{vap}}{ \rho g }$
#
# </details>

# %% [markdown]
# ## PART · 4. 액체로켓엔진의 시험 및 평가(Test and Evaluation of LREs)
#
# > 핵심 질문 — "엔진을 완성하기 위해 시험과 평가는 어떻게 이루어지는가?"

# %% [markdown]
# `4.1 액체로켓엔진 시험 및 평가(LRE Test and Evaluation)`
#
# ## 시험설비
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - KSLV-II의 전체 개발 로직 및 시험설비 구성
#
# | 터보펌프 실매질설비 |  |
# |---|---|
# | - 조립체 실매질 수류시험 |  |
#
# | 터보펌프 대형상사설비 |  |
# |---|---|
# | 펌프 상사수류시험, 터빈 상사수류시험, 조립체 상사수류시험 |  |
#
# | 엔진 지상연소시험설비, 엔진 고공연소시험설비, 3단 엔진 연소시험설비 |  |
# |---|---|
# | 지상조건 연소시험, 고공조건 연소시험, 비행환경 모사시험 |  |
#
# - 엔진시스템 조립
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img006.jpg)
#
# - 추진기관 시스템 조립
#
# | 추진기관 시스템 시험설비 |
# |---|
# | 지상조건 수류시험, 지상조건 연소시험, 추진시스템 최종 검증 |
# |  |
#
# | 추진공급계 시험설비 |  |
# |---|---|
# | 엔진공급계 개발시험, 기체공급계 개발시험 |  |
#
# | 연소기 연소시험설비 |  |
# |---|---|
# | 연소기·가스발생기 수류시험, 연소기·가스발생기 연소시험, 연소기·가스발생기 성능확인 |  |
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img011.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img012.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img013.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img014.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img015.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img016.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img017.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img018.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img019.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img020.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img021.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img022.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img023.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img024.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img025.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img026.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img027.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img028.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img029.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img030.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img031.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img032.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img033.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img034.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img035.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img036.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img037.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img038.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img039.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img040.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img041.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img042.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img043.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img044.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img045.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img046.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s126_img047.jpg)
#
# </details>

# %% [markdown]
# `4.1 액체로켓엔진 시험(Test of LREs)`
#
# ## 핵심 용어
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 개발시험(Development test) :
#   - 설계 성숙도 확보, 성능 입증, 인증 프로그램의 리스크 저감
#   - 검증된 개념·기법을 새로운 형상에 적용하거나 신규 설계 개념을 검증
#   - 개념설계 단계에서 운용단계로의 설계 진화를 지원
#   - 설계 변경사항 검증
#   - 인증·비행용 하드웨어 제작 착수에 따른 리스크 저감
#   - 인증·수락시험 절차의 개발 및 검증
#   - 인증 성공 이후 발생한 문제·이슈 조사
# - 인증시험(Qualification test) :
#   - 설계·제작공정·수락 프로그램이 다회의 재작업·재시험을 감당할 충분한 여유를 갖고 규격 요구조건을 만족하는 하드웨어/소프트웨어를 만드는지 입증
#   - 아울러 인증시험은 시험기법·절차·장비·계측·소프트웨어를 포함해 계획된 수락 프로그램 전반을 검증해야 함
# - 수락시험(Acceptance test) :
#   - 각 납품 품목이 성능규격을 충족하고 제작상 결함이 없음을 입증
#   - 부품·공정·소재·작업상의 잠재결함으로 인한 초기고장을 유발하기 위한 스트레스 스크리닝
#   - 벤치 레벨 부품 수락시험은 엔진 수락시험의 리스크를 줄이는 데 유용하나, 엔진 실제 환경을 충분히 모사하지 못할 수 있음
# - 출처 : AIAA LRE Course
#
# </details>

# %% [markdown]
# ## 전형적인 시험 순서(Typical Sequence of Testing)
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 출처 : AIAA LRE Course
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s128_img002.png)
#
# </details>

# %% [markdown]
# ## LOX/RP 및 LOX/LH 엔진 개발 프로그램 현황
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - Emdee, J., "A Survey of Development Test Programs for Hydrogen Oxygen Rocket Engines," AIAA Paper No. 2001-0749.
# - Emdee, J., "A Survey of Development Test Programs for LOX/Kerosene Liquid Rocket Engines," AIAA Paper No. 2001-3985.
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s129_img002.png)
#
# </details>

# %% [markdown]
# ## 개발 소요
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# |  | 설계·개발 기간 | 시험시간(초) 누적 |  | 연소시험 횟수 |  | 신규 시험엔진 대수 |  |
# |---|---|---|---|---|---|---|---|
# |  | 최근 이력 평균 | 최근 이력 평균 | 고성공률 경향 | 최근 이력 평균 | 고성공률 경향 | 최근 이력 평균 | 고성공률 경향 |
# | 신규 부스터 | 평균 10년 (9-11년) | 평균 90,000 (16,000-163,000) | 40,000 | 평균 500 (280-800) | 400 | 평균 16 (14-20) | 15 |
# | 신규 상단 | 평균 7년 (6-8년) | 평균 28,000 (25,000-30,000) | 40,000 | 평균 200 (120-320) | 400 | 평균 10 (8-11) | 15 |
# | 부스터 개량형 | 평균 2년 (1-3년) | 평균 7,000 (1,000-15,000) | - | 평균 40 (20-100) | - | 평균 4 (1-11) | - |
# | 상단 개량형 | 평균 3년 (1-5년) | 평균 15,000 (6,000-20,000) | - | 평균 100 (50-150) | - | 평균 5 (2-10) | - |
#
# - 신규 부스터 엔진의 개발 기간은 약 10년, 상단 엔진은 약 7년 소요됨
# - M.J. Adams and etc., "Liquid Engine Test Facilities Assessment", 2002.5, The Aerospace Corporation
#
# </details>

# %% [markdown]
# ## 엔진 개발 기간과 연소시험 횟수
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 엔진 신뢰성 확보를 위해 수백 회의 시험이 필요함
# 개발에 투입되는 엔진 대수와 시험 횟수는 사례마다 상이함
# - 해외 주요 엔진(LOx/케로신)의 연소시험 횟수 사례
#
# |  | 엔진 대수 | 시험 횟수 | 누적 시험시간(초) | 비행시간(초) | 시험횟수/엔진대수 | 누적시험시간/엔진대수 | 시험/비행시간 비율 |
# |---|---|---|---|---|---|---|---|
# | NK-15/NK-15B | 199 | 450 | 40,200 | 103 | 2 | 202 | 2.0 |
# | RD-171 | 80 | 275 | 25,000 | 150 | 3 | 313 | 2.1 |
# | FASTRAC | 5 | 42 | 888 | 155 | 8 | 178 | 1.1 |
# | RD-180 | 11 | 95 | 15,574 | 150 | 9 | 1416 | 9.4 |
# | RD-0120 | 90 | 793 | 163,000 | 600 | 9 | 1811 | 3.0 |
# | RS-68 | 12 | 183 | 18,945 | 249 | 15 | 1579 | 6.3 |
# | Vulcain | 14 | 278 | 87,000 | 605 | 20 | 6214 | 10.3 |
# | LE-7 | 14 | 282 | 15,639 | 346 | 20 | 1117 | 3.2 |
# | SSME | 20 | 726 | 110,253 | 480 | 36 | 5513 | 11.5 |
# | LE-5 | 8 | 322 | 27,706 | 370 | 40 | 3463 | 9.4 |
# | F-1 | 56 | 2,805 | 252,958 | 161 | 50 | 4517 | 28.1 |
# | RS-27A | 1 | 22 |  |  | 22 |  |  |
# | MA-3 booster | 2 | 39 | 3899 | 120 | 20 | 1949 | 16.2 |
# | LR87-AJ-1 | 1 | 46 | 3579 | 138 | 46 | 3579 | 23.9 |
# | LR91-AJ-1 | 1 | 39 | 2933 | 225 | 39 | 2933 | 13.0 |
# | MA-5A booster | 1 | 29 | 748 | 174 | 29 | 748 | 4.3 |
# | MA-5A sustainer | 1 | 12 | 716 | 289 | 12 | 716 | 2.5 |
# | RL10 3-3A, B | 3 |  |  |  | 20 | 4500 | 7.0 |
#
# </details>

# %% [markdown]
# ## 엔진 개발 예산과 개발시험 비용
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 시험은 엔진 전체 개발비의 20~25%를 차지함
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s132_img002.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s132_img003.jpg)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s132_img004.jpg)
#
# - J-2
# - F-1
# - Space Shuttle Main Engine (SSME)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s132_img008.jpg)
#
# - F-100 (항공엔진)
#
# </details>

# %% [markdown]
# ## 나로우주센터 시험설비
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img001.png)
#
# - 추진기관 및 엔진 시험설비 구축 완료
# - 나로우주센터
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img004.png)
#
# - 항우연
# - 추진공급계 및 터보펌프 대형상사 시험설비
# - 산업체(창원)
# - 엔진 조립/기능 시험설비
# - 연소기
# - 연소시험설비
# - 추진기관
# - 시스템 시험설비
# - 엔진 고공
# - 터보펌프
# - 실매질 시험설비
# - 3단엔진
# - 엔진 지상
# - 제어계측동
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img016.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img017.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img018.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img019.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img020.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img021.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img022.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img023.png)
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s133_img024.png)
#
# </details>

# %% [markdown]
# ## 엔진 연소시험설비의 특징
#
# <details>
# <summary>📖 클릭하여 핵심 내용 보기</summary>
#
# - 고저차(건물 높이[하단부])
# - 엔진 배기화염의 안전 배출 목적
# - 엔진 지상연소시험설비 건물 : 48.4m[28.7m]
# - 엔진 고공연소시험설비 건물 : 58.0m(38.3m)
# - 3단 엔진연소시험설비 건물 : 35.1m[19.7m]
# - (2) 1m 이상의 방벽
# - 화재·연료 안전을 위한 방호벽 — 산화제와의 화염 전파를 방지
# - (3) 추력 전달 구조물
# - 추진력 전달 시 흔들림·휨이 없어야 함
# - (4) 추력 보정(측정)
# - 휨이 없어야 함
#
# ![](https://raw.githubusercontent.com/gabraxas/LVs-and-Policy/main/lecture/week02/assets/s134_img002.jpg)
#
# </details>

# %% [markdown]
# ## PART · 6. 맺음말(Concluding Remarks)
